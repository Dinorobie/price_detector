# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import time
import math
import pandas as pd

# %%
# Number of pages to visit
page = 50
counter = 0

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\Vivi\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
#URL_rent
# https://www.lamudi.com.mx/distrito-federal/casa/for-sale/?currency=mxn&page
# https://www.lamudi.com.mx/distrito-federal/departamento/for-sale/?currency=mxn&page
# https://www.lamudi.com.mx/distrito-federal/departamento/for-rent/?currency=mxn&page
# https://www.lamudi.com.mx/distrito-federal/casa/for-rent/?currency=mxn&page

# %%
list_bathrooms=[]
list_bedrooms=[]
list_rooms_total=[]
list_building_size=[]
list_car_spaces=[]
list_category=[]
list_furnished=[]
list_coordinates=[]
list_location=[]
list_land_size=[]
list_price=[]
list_id=[]
list_subcategory=[]
list_year_built=[]
list_description=[]
list_link=[]

# %%
for i in range(0,page):
    counter = counter + 1 
    counter_str = str(counter)
    url = 'https://www.lamudi.com.mx/distrito-federal/casa/for-rent/?currency=mxn&page' + counter_str
    browser.visit(url)
    html = browser.html
    soup = bs(html, 'html.parser')
    
    des=[]
    features = soup.find_all('div', class_="ListingCell-AllInfo ListingUnit")
    other_features = soup.find_all('a', class_= 'js-listing-link ellipsis')
    
    for i in features:
        extra_features=soup.find_all('div', class_="ListingCell-shortDescription")
        for i in range(len(extra_features)):
            d=extra_features[i].get_text(strip = True).replace("\n\n", "").replace("\n", " ").replace("\t", "").replace("\xa0", "")
            des.append(d) 
    loc=[]        
    location=soup.find_all('span', class_="ListingCell-KeyInfo-address-text")
    for i in range(len(location)):
        l=location[i].get_text(strip = True).replace("\n\n", "").replace("\n", " ")
        loc.append(l) 
        
    for i in range(0,30):
      
        try:
            bathrooms=features[i]['data-bathrooms']
            list_bathrooms.append(bathrooms)
        except:
            bathrooms="uknown"
            list_bathrooms.append(bathrooms)  
            
        try:    
            bedrooms=features[i]['data-bedrooms']
            list_bedrooms.append(bedrooms)       
        except:
            bedrooms="unknown"
            list_bedrooms.append(bedrooms)
                
        try:
            rooms_total=features[i]['data-rooms_total']
            list_rooms_total.append(rooms_total)
        except:
            rooms_total="unknown"
            list_rooms_total.append(rooms_total)

            
        try:    
            building_size=features[i]['data-building_size']
            list_building_size.append(building_size)
        except:
            building_size="unknown"
            list_building_size.append(building_size)          

            
        try:
            car_spaces=features[i]['data-car_spaces']
            list_car_spaces.append(car_spaces)   
        except:
            car_spaces="unknown"
            list_car_spaces.append(car_spaces)

            
        try:
            category=features[i]['data-category']
            list_category.append(category)
        except:
            category="unknown"
            list_category.append(category)

            
        try:
            furnished=features[i]['data-furnished']
            list_furnished.append(furnished)
        except:
            furnished="unknown"
            list_furnished.append(furnished)

            
        try:
            coordinates=features[i]['data-geo-point']
            list_coordinates.append(coordinates)
        except:
            coordinates="unknown"
            list_coordinates.append(coordinates)
            
        try:
            location=loc[i]
            list_location.append(location)
        except:
            location="unknown"
            list_location.append(location)    

            
        try:
            land_size=features[i]['data-land_size']
            list_land_size.append(land_size)
        except:
            land_size="unknown"
            list_land_size.append(land_size)

            
        try:
            price=features[i]['data-price']
            list_price.append(price)
        except:
            price="unknown"
            list_price.append(price)

            
        try:
            id=features[i]['data-sku']
            list_id.append(id)
        except:
            id="unknown"
            list_id.append(id)

            
        try:
            subcategory=features[i]['data-subcategories']
            list_subcategory.append(subcategory)
        except:
            subcategory="unknown"
            list_subcategory.append(subcategory)

            
        try:
            year_built=features[i]['data-year_built']
            list_year_built.append(year_built)
        except:
            year_built="unknown"
            list_year_built.append(year_built)

            
        try:
            description=des[i]
            list_description.append( description)
        except:
            description="unknown"
            list_description.append( description)

            
        try:
            link=other_features[i]['href']
            list_link.append(link)
        except:
            link="unknown"
            list_link.append(link)

# %%
dict = {"bathrooms":list_bathrooms,
        "bedrooms":list_bedrooms,
        "rooms_total":list_rooms_total,
        "building_size":list_building_size,
        "car_spaces":list_car_spaces,
        "category":list_category,
        "furnished":list_furnished,
        "coordinates":list_coordinates,
        "location":list_location,
        "land_size":list_land_size,
        "price":list_price,
        "id":list_id,
        "subcategory":list_subcategory,
        "year_built": list_year_built,
        "description":list_description,
        "link":list_link
        }

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      bathrooms bedrooms rooms_total building_size car_spaces category  \
# 0          2.5        3     unknown           125          2     casa
# 1            2        2           4           250          3     casa
# 2            3        4           7           245          4     casa
# 3            4        4           8           876          4     casa
# 4            3        3     unknown           400          3     casa
# ...        ...      ...         ...           ...        ...      ...
# 2995       3.5        3     unknown           370          3     casa
# 2996         2        3           3           119          4     casa
# 2997         3        4           7           400          4     casa
# 2998         3        3           6           450          4     casa
# 2999         3        3     unknown           350          4     casa
#
#      furnished               coordinates  \
# 0                   [-99.23219,19.34179]
# 1                    [-99.1347,19.48776]
# 2                [-99.239685,19.3145216]
# 3               [-99.2039725,19.3006043]
# 4                 [-99.218889,19.420556]
# ...        ...                       ...
# 2995                 [-99.2977,19.34711]
# 2996                  [-99.1678,19.2655]
# 2997            [-99.2724224,19.3863521]
# 2998             [-99.288499,19.3515894]
# 2999                [-99.28222,19.35719]
#
#                                            location land_size  price  \
# 0                          Tetelpan, Álvaro Obregón       162  20400
# 1               Lindavista Norte, Gustavo A. Madero       120  31500
# 2       San Jerónimo Lídice, La Magdalena Contreras       193  43000
# 3                   Jardines en la Montaña, Tlalpan       465  87000
# 4              Lomas de Chapultepec, Miguel Hidalgo       560  56500
# ...                                             ...       ...    ...
# 2995               Contadero, Cuajimalpa de Morelos       370  45000
# 2996                      San Pedro Mártir, Tlalpan       143  17000
# 2997  Lomas de Vista Hermosa, Cuajimalpa de Morelos         0   5500
# 2998               Contadero, Cuajimalpa de Morelos       470  55000
# 2999     Santa Fe Cuajimalpa, Cuajimalpa de Morelos       300  45000
#
#                      id                    subcategory year_built  \
# 0     HO611D39A751FFEMX  ["casa","casa-en-condominio"]    unknown
# 1     HO611E01157E13CMX  ["casa","casa-en-condominio"]       2016
# 2     HO5DE0E7D598F2BMX  ["casa","casa-en-condominio"]       2021
# 3     HO611CB1FAF2CB3MX    ["casa","casa-unifamiliar"]       2021
# 4     HO6111D81CCDAA3MX    ["casa","casa-unifamiliar"]    unknown
# ...                 ...                            ...        ...
# 2995  HO60C91BBD45292MX  ["casa","casa-en-condominio"]    unknown
# 2996  HO60B2F1D693295MX    ["casa","casa-unifamiliar"]       2014
# 2997  HO610CFB680F228MX    ["casa","casa-unifamiliar"]       2021
# 2998  HO5F1FC66532B3AMX    ["casa","casa-unifamiliar"]       2010
# 2999  HO60D49D67B366AMX           ["casa","townhouse"]    unknown
#
#                                             description  \
# 0     Hermosa casa en condominio a una cuadra de Des...
# 1     Construcción 250m2Preciosa casa construida en ...
# 2     Construída por el Arq. Cramer, con su increíbl...
# 3     - vestíbulo recibidor,  baño y closet de visit...
# 4     Casa muy iluminada Hermoso jardin En una sóla ...
# ...                                                 ...
# 2995  Preciosa casa contemporánea casi nueva, en exc...
# 2996  Wiggot: p7RnrCC Ubicación privilegiada de esta...
# 2997  EXCELENTE CASA  Casa de 2 niveles, 4 habitacio...
# 2998  Gran casa con todos los servicios de la gran c...
# 2999  Bonita y acogedora casa en Santa Fe, lista par...
#
#                                                    link
# 0     https://www.lamudi.com.mx/hermosa-casa-en-rent...
# 1     https://www.lamudi.com.mx/casa-en-renta-privad...
# 2     https://www.lamudi.com.mx/casa-en-venta-en-con...
# 3     https://www.lamudi.com.mx/en-venta-y-renta-her...
# 4     https://www.lamudi.com.mx/casa-en-una-sola-pla...
# ...                                                 ...
# 2995  https://www.lamudi.com.mx/hermosa-casa-en-cond...
# 2996  https://www.lamudi.com.mx/renta-de-casa-en-con...
# 2997  https://www.lamudi.com.mx/la-palma-lomas-de-vi...
# 2998  https://www.lamudi.com.mx/casa-en-renta-en-el-...
# 2999  https://www.lamudi.com.mx/renta-casa-con-incre...
#
# [3000 rows x 16 columns]

# %%
#df.to_csv('lamudi_houses_sale.csv')
df.to_csv('lamudi_houses_rent.csv')
# df.to_csv('lamudi_departments_rent.csv')
# df.to_csv('lamudi_departments_sale.csv')

# %%
browser.quit()
