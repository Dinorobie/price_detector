# %% [markdown]
# # Viva anuncios scrapper

# %% [markdown]
# ### Set-up

# %%
# Dependencies and libraries
import requests
import pandas as pd
import re
import json

from bs4 import BeautifulSoup
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\Juanjo\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
# Loading page
url = 'https://www.vivanuncios.com.mx/s-venta-inmuebles/distrito-federal/v1c1097l1008p1'
browser.visit(url)

# %%
# Getting the page
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup2 = soup.findAll('div', class_='tileV2 REAdTileV2 regular mapView')

# %%
id = 1
scrapped_data = {id:{}}
for ad in soup2:
    scrapped_data[id]['price'] = (ad.find(class_="ad-price").text)
    try:
        scrapped_data[id]['square_meters'] = (ad.find(class_="chiplets-inline-block surface-area").text)
    except:
        scrapped_data[id]['square_meters'] = ('0')
    try:
        scrapped_data[id]['bedrooms'] = (ad.find(class_="chiplets-inline-block re-bedroom").text)
    except:
        scrapped_data[id]['bedrooms'] = ('0')
    try:
        scrapped_data[id]['bathrooms'] = (ad.find(class_="chiplets-inline-block re-bathroom").text)
    except:
        scrapped_data[id]['bathrooms'] = ('0')
    try:
        scrapped_data[id]['parking_spaces'] = (ad.find(class_="chiplets-inline-block car-parking").text)
    except:
        scrapped_data[id]['parking_spaces'] = ('0')
    try:
        scrapped_data[id]['address'] = (ad.find(class_="tile-location one-liner").text)
    except:
        scrapped_data[id]['address'] = ('0')
    try:
        scrapped_data[id]['description'] = (ad.find(class_="href-link tile-title-text").text)
    except:
        scrapped_data[id]['description'] = ('0')
    id += 1
    scrapped_data[id] = {'price':[], 'square_meters':[], 'bedrooms': [], 'bathrooms': [],
                         'parking_spaces': [], 'address':[], 'description':[]}
scrapped_data
# Out:
# {1: {'price': '\n                    $3,200,000\n                    \n                ',
#   'square_meters': '148 m²',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Casa la Salle',
#   'description': 'Tamaulipas Estado de Hidalgo'},
#  2: {'price': '\n                    $2,570,530\n                    \n                ',
#   'square_meters': '57 m²',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Obrera',
#   'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'},
#  3: {'price': '\n                    $1,210,100\n                    \n                ',
#   'square_meters': '105 m²',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'parking_spaces': '2',
#   'address': 'Lindavista Nte.',
#   'description': 'LA MEJOR CASA AL MEJOR PRECIO'},
#  4: {'price': '\n                    $5,936,000\n                    \n                ',
#   'square_meters': '80 m²',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '2',
#   'address': 'Héroes de Padierna',
#   'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'},
#  5: {'price': '\n                    $4,250,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Lomas de Santa Fe',
#   'description': 'Departamento - Santa Fe Cuajimalpa'},
#  6: {'price': '\n                    $23,000,000\n                    \n                ',
#   'square_meters': '588 m²',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '0',
#   'address': 'Contadero',
#   'description': 'Casa en condominio - Contadero'},
#  7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '0',
#   'address': 'Fracc Club de Golf Bosques',
#   'description': 'Departamento - Club de Golf Bosques'},
#  8: {'price': '\n                    $3,000,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Guerrero',
#   'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'},
#  9: {'price': '\n                    $850,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.',
#   'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'},
#  10: {'price': '\n                    $7,980,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Lomas de Sta Fé',
#   'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'},
#  11: {'price': '\n                    $6,785,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Actipan',
#   'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'},
#  12: {'price': '\n                    $2,900,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '1',
#   'address': 'Parque San Andrés',
#   'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'},
#  13: {'price': '\n                    $3,690,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Cd. de los Deportes',
#   'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'},
#  14: {'price': '\n                    $18,000,000\n                    \n                ',
#   'square_meters': '475 m²',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '4+',
#   'address': 'Miguel Hidalgo Villa Olímpica',
#   'description': 'Residencia en Venta con excelente proyecto arquitectónico'},
#  15: {'price': '\n                    $2,700,000\n                    \n                ',
#   'square_meters': '73 m²',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'La Preciosa',
#   'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'},
#  16: {'price': '\n                    $52,000,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '4+',
#   'address': 'Bosque de las Lomas',
#   'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'},
#  17: {'price': '\n                    $13,600,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '3',
#   'address': 'Lomas de Santa Fe',
#   'description': 'Departamento en Venta en Santa Fe'},
#  18: {'price': '\n                    $3,025,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Refinería 18 de Marzo',
#   'description': 'DEPARTAMENTO VENTA A 20 MIN DE POLANCO OPORTUNIDAD ULTIMOS CON DESCUENTO'},
#  19: {'price': '\n                    $11,450,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '1',
#   'address': 'Col del Valle Sur',
#   'description': 'DEPARTAMENTO VENTA COL Del Valle'},
#  20: {'price': '\n                    $12,480,000\n                    \n                ',
#   'square_meters': '340 m²',
#   'bedrooms': '4',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Periodista',
#   'description': 'Venta Hermosa Residencia en Col. Periodista'},
#  21: {'price': '\n                    $48,000\n                    \n                ',
#   'square_meters': '213 m²',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '2',
#   'address': 'Col del Valle Centro',
#   'description': 'RENTA PENTHAUSE COL DEL VALLE 3 RECAMARAS 2 ESTACIONAMIENTOS ROOF GARDEN PRIVADO'},
#  22: {'price': '\n                    $2,850,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'San Lorenzo Tlaltenango',
#   'description': 'VENTA DEPARTAMENTO URGE 15 MIN POLANCO 2 RECAMARAS 2 ESTACIONAMIENTOS'},
#  23: {'price': '\n                    $2,500,000\n                    \n                ',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Lomas de Sotelo',
#   'description': 'DEPARTAMENTO VENTA LOMAS DE SOTELO A 5 MIN DE POLANCO 3 RECAMARAS'},
#  24: {'price': [],
#   'square_meters': [],
#   'bedrooms': [],
#   'bathrooms': [],
#   'parking_spaces': [],
#   'address': [],
#   'description': []}}

# %% [markdown]
# ### Reformatting

# %%
i = 1
for i in range(1,len(scrapped_data)+1):
    # Reformatting price
    scrapped_data[i]['price'] = re.sub("[^0-9]", "", scrapped_data[i]['price'])
    # Reformatting square meters
    scrapped_data[i]['square_meters'] = re.sub("[^0-9]", "", scrapped_data[i]['square_meters'])
    
    print (scrapped_data)
# Out:
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '\n                    $2,570,530\n                    \n                ', 'square_meters': '57 m²', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '\n                    $1,210,100\n                    \n                ', 'square_meters': '105 m²', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '\n                    $5,936,000\n                    \n                ', 'square_meters': '80 m²', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '\n                    $4,250,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '\n                    $23,000,000\n                    \n                ', 'square_meters': '588 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departame ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '\n                    $1,210,100\n                    \n                ', 'square_meters': '105 m²', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '\n                    $5,936,000\n                    \n                ', 'square_meters': '80 m²', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '\n                    $4,250,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '\n                    $23,000,000\n                    \n                ', 'square_meters': '588 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price' ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '\n                    $5,936,000\n                    \n                ', 'square_meters': '80 m²', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '\n                    $4,250,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '\n                    $23,000,000\n                    \n                ', 'square_meters': '588 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n         ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '\n                    $4,250,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '\n                    $23,000,000\n                    \n                ', 'square_meters': '588 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '\n                    $23,000,000\n                    \n                ', 'square_meters': '588 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'descr ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '\n                    $2,750,000\n                    \n                        USD\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOS ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '\n                    $3,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '\n                    $13,600,000\n                    \n                ' ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '\n                    $850,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '\n                    $13,600,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parki ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '\n                    $7,980,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '\n                    $13,600,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description':  ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '7980000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '\n                    $6,785,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '\n                    $13,600,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description': 'Departamento en Venta en Santa Fe'}, 18: {'price': '\n           ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '7980000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '6785000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '\n                    $2,900,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '\n                    $3,690,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '\n                    $18,000,000\n                    \n                ', 'square_meters': '475 m²', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '\n                    $2,700,000\n                    \n                ', 'square_meters': '73 m²', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '\n                    $52,000,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '\n                    $13,600,000\n                    \n                ', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description': 'Departamento en Venta en Santa Fe'}, 18: {'price': '\n                    $3,025,000\n                    \n                ', 's ...
# ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '7980000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '6785000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '2900000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '3690000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '18000000', 'square_meters': '475', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '2700000', 'square_meters': '73', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '52000000', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '13600000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description': 'Departamento en Venta en Santa Fe'}, 18: {'price': '3025000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Refinería 18 de Marzo', 'description': 'DEPARTAMENTO VENTA A 20 MIN DE POLANCO OPORTUNIDAD ULTIMOS CON DESCUENTO'}, 19: {'price': '11450000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Col del Valle Sur', 'description': 'DEPARTAMENTO VENTA COL Del Valle'}, 20: {'price': '12480000', 'square_meters': '340', 'bedrooms': '4' ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '7980000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '6785000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '2900000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '3690000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '18000000', 'square_meters': '475', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '2700000', 'square_meters': '73', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '52000000', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '13600000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description': 'Departamento en Venta en Santa Fe'}, 18: {'price': '3025000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Refinería 18 de Marzo', 'description': 'DEPARTAMENTO VENTA A 20 MIN DE POLANCO OPORTUNIDAD ULTIMOS CON DESCUENTO'}, 19: {'price': '11450000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Col del Valle Sur', 'description': 'DEPARTAMENTO VENTA COL Del Valle'}, 20: {'price': '12480000', 'square_meters': '340', 'bedrooms': '4' ...
# {1: {'price': '3200000', 'square_meters': '148', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Casa la Salle', 'description': 'Tamaulipas Estado de Hidalgo'}, 2: {'price': '2570530', 'square_meters': '57', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Obrera', 'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'}, 3: {'price': '1210100', 'square_meters': '105', 'bedrooms': '3', 'bathrooms': '1', 'parking_spaces': '2', 'address': 'Lindavista Nte.', 'description': 'LA MEJOR CASA AL MEJOR PRECIO'}, 4: {'price': '5936000', 'square_meters': '80', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '2', 'address': 'Héroes de Padierna', 'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'}, 5: {'price': '4250000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Santa Fe', 'description': 'Departamento - Santa Fe Cuajimalpa'}, 6: {'price': '23000000', 'square_meters': '588', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '0', 'address': 'Contadero', 'description': 'Casa en condominio - Contadero'}, 7: {'price': '2750000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '0', 'address': 'Fracc Club de Golf Bosques', 'description': 'Departamento - Club de Golf Bosques'}, 8: {'price': '3000000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Guerrero', 'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'}, 9: {'price': '850000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '1', 'parking_spaces': '1', 'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.', 'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'}, 10: {'price': '7980000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '0', 'address': 'Lomas de Sta Fé', 'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'}, 11: {'price': '6785000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Actipan', 'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'}, 12: {'price': '2900000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Parque San Andrés', 'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'}, 13: {'price': '3690000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Cd. de los Deportes', 'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'}, 14: {'price': '18000000', 'square_meters': '475', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Miguel Hidalgo Villa Olímpica', 'description': 'Residencia en Venta con excelente proyecto arquitectónico'}, 15: {'price': '2700000', 'square_meters': '73', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'La Preciosa', 'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'}, 16: {'price': '52000000', 'square_meters': '0', 'bedrooms': '4', 'bathrooms': '4+', 'parking_spaces': '4+', 'address': 'Bosque de las Lomas', 'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'}, 17: {'price': '13600000', 'square_meters': '0', 'bedrooms': '3', 'bathrooms': '3', 'parking_spaces': '3', 'address': 'Lomas de Santa Fe', 'description': 'Departamento en Venta en Santa Fe'}, 18: {'price': '3025000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '2', 'address': 'Refinería 18 de Marzo', 'description': 'DEPARTAMENTO VENTA A 20 MIN DE POLANCO OPORTUNIDAD ULTIMOS CON DESCUENTO'}, 19: {'price': '11450000', 'square_meters': '0', 'bedrooms': '2', 'bathrooms': '2', 'parking_spaces': '1', 'address': 'Col del Valle Sur', 'description': 'DEPARTAMENTO VENTA COL Del Valle'}, 20: {'price': '12480000', 'square_meters': '340', 'bedrooms': '4' ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-54b173c9e7df> in <module>()
#       2 for i in range(1,len(scrapped_data)+1):
#       3     # Reformatting price
# ----> 4     scrapped_data[i]['price'] = re.sub("[^0-9]", "", scrapped_data[i]['price'])
#       5     # Reformatting square meters
#       6     scrapped_data[i]['square_meters'] = re.sub("[^0-9]", "", scrapped_data[i]['square_meters'])
#
# C:\Users\Juanjo\anaconda3\envs\PythonData\lib\re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
scrapped_data
# Out:
# {1: {'price': '3200000',
#   'square_meters': '148',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Casa la Salle',
#   'description': 'Tamaulipas Estado de Hidalgo'},
#  2: {'price': '2570530',
#   'square_meters': '57',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Obrera',
#   'description': 'Departamento en Preventa en Parque Central, Cuauhtémoc, CDMX, 2 Recámaras'},
#  3: {'price': '1210100',
#   'square_meters': '105',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'parking_spaces': '2',
#   'address': 'Lindavista Nte.',
#   'description': 'LA MEJOR CASA AL MEJOR PRECIO'},
#  4: {'price': '5936000',
#   'square_meters': '80',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '2',
#   'address': 'Héroes de Padierna',
#   'description': 'Casa en Preventa en Residencial Cumbres Ajusco, Tlalpan, CDMX, 3 Recámaras'},
#  5: {'price': '4250000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Lomas de Santa Fe',
#   'description': 'Departamento - Santa Fe Cuajimalpa'},
#  6: {'price': '23000000',
#   'square_meters': '588',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '0',
#   'address': 'Contadero',
#   'description': 'Casa en condominio - Contadero'},
#  7: {'price': '2750000',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '0',
#   'address': 'Fracc Club de Golf Bosques',
#   'description': 'Departamento - Club de Golf Bosques'},
#  8: {'price': '3000000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Guerrero',
#   'description': 'VENTA DEPARTAMENTO CENTRICO POR REFORMA'},
#  9: {'price': '850000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Zona Urbana Ejidal Santa Martha Acatitla Nte.',
#   'description': 'VENDO SANTA MARTA ACATITLA USA TU CREDITO'},
#  10: {'price': '7980000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '0',
#   'address': 'Lomas de Sta Fé',
#   'description': 'RESIDENCIAL INFINITY EN SANTA FE, SE VENDE DEPARTAMENTO'},
#  11: {'price': '6785000',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Actipan',
#   'description': 'DEPARTAMENTO EN VENTA O RENTA NUEVO COLONIA ACTIPAN'},
#  12: {'price': '2900000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '1',
#   'address': 'Parque San Andrés',
#   'description': 'ZONA DE COYOACAN, DEPARTAMENTO EN VENTA'},
#  13: {'price': '3690000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Cd. de los Deportes',
#   'description': 'DEPARTAMENTO  EN VENTA cerca NAPOLES, CIUDAD DE LOS DEPORTES'},
#  14: {'price': '18000000',
#   'square_meters': '475',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '4+',
#   'address': 'Miguel Hidalgo Villa Olímpica',
#   'description': 'Residencia en Venta con excelente proyecto arquitectónico'},
#  15: {'price': '2700000',
#   'square_meters': '73',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'La Preciosa',
#   'description': 'Excelente Departamento en la Calle Centeotl en Azcapotzalco $ 2,700,000'},
#  16: {'price': '52000000',
#   'square_meters': '0',
#   'bedrooms': '4',
#   'bathrooms': '4+',
#   'parking_spaces': '4+',
#   'address': 'Bosque de las Lomas',
#   'description': 'RESIDENCIA TOTALMENTE REMODELADA CON ALBERCA Y CINE EN BOSQUES DE LAS LOMAS $ 52M'},
#  17: {'price': '13600000',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '3',
#   'address': 'Lomas de Santa Fe',
#   'description': 'Departamento en Venta en Santa Fe'},
#  18: {'price': '3025000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Refinería 18 de Marzo',
#   'description': 'DEPARTAMENTO VENTA A 20 MIN DE POLANCO OPORTUNIDAD ULTIMOS CON DESCUENTO'},
#  19: {'price': '11450000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '1',
#   'address': 'Col del Valle Sur',
#   'description': 'DEPARTAMENTO VENTA COL Del Valle'},
#  20: {'price': '12480000',
#   'square_meters': '340',
#   'bedrooms': '4',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'Periodista',
#   'description': 'Venta Hermosa Residencia en Col. Periodista'},
#  21: {'price': '48000',
#   'square_meters': '213',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'parking_spaces': '2',
#   'address': 'Col del Valle Centro',
#   'description': 'RENTA PENTHAUSE COL DEL VALLE 3 RECAMARAS 2 ESTACIONAMIENTOS ROOF GARDEN PRIVADO'},
#  22: {'price': '2850000',
#   'square_meters': '0',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'parking_spaces': '2',
#   'address': 'San Lorenzo Tlaltenango',
#   'description': 'VENTA DEPARTAMENTO URGE 15 MIN POLANCO 2 RECAMARAS 2 ESTACIONAMIENTOS'},
#  23: {'price': '2500000',
#   'square_meters': '0',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'parking_spaces': '1',
#   'address': 'Lomas de Sotelo',
#   'description': 'DEPARTAMENTO VENTA LOMAS DE SOTELO A 5 MIN DE POLANCO 3 RECAMARAS'},
#  24: {'price': [],
#   'square_meters': [],
#   'bedrooms': [],
#   'bathrooms': [],
#   'parking_spaces': [],
#   'address': [],
#   'description': []}}

# %%
# Closing browser
browser.quit()

# Saving the data to a json
with open('viva_anuncios.json', 'w') as fp:
